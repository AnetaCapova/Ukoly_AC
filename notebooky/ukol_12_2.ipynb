# %%
import requests

r = requests.get("https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/platy_2021_02.csv")
open("platy_2021_02.csv", "wb").write(r.content)
# Out:
# 492

# %%
import pandas

# %%
# Načti si tato data do tabulky a vytvoř histogram. 

platy = pandas.read_csv("platy_2021_02.csv")
platy
# Out:
#     cislo_zamestnance     plat
# 0                   3  54900.0
# 1                   6  54800.0
# 2                   7  36400.0
# 3                   8  47900.0
# 4                  16  34200.0
# 5                  18  35400.0
# 6                  21  54200.0
# 7                  22  34400.0
# 8                  23  39000.0
# 9                  24  44200.0
# 10                 26  59600.0
# 11                 27  45100.0
# 12                 28  38100.0
# 13                 29  48900.0
# 14                 30  33500.0
# 15                 32  53000.0
# 16                 33  38400.0
# 17                 34  36800.0
# 18                 38  32600.0
# 19                 40  32800.0
# 20                 41  49300.0
# 21                 44  52000.0
# 22                 47  40700.0
# 23                 49  58400.0
# 24                 51  37100.0
# 25                 56  39300.0
# 26                 57  36800.0
# 27                 63  31400.0
# 28                 64  36900.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
platy.hist()
plt.show()

# %%
# Nastav vhodně hranice skupin histogramu (parametr bins), aby byl graf přehledný a snadno interpretovatelný.

platy.hist(bins=[
 25000, 30000, 35000, 40000, 45000, 50000, 55000, 60000
],
color="0")

plt.show()

# %%
import requests

r = requests.get("https://raw.githubusercontent.com/andywaltlova/python-1-podzim-2022/master/ukoly/data/temperature.csv")
open("temperature.csv", "wb").write(r.content)
# Out:
# 316099

# %%
# Vytvoř tabulku, která bude obsahovat údaje o teplotě za města Helsinki, Miami Beach a Tokyo.

teplota = pandas.read_csv("temperature.csv")
teplota
# Out:
#              Region  Country      City  Day  AvgTemperature
# 0            Africa  Algeria   Algiers    1            62.0
# 1            Africa  Algeria   Algiers    2            62.2
# 2            Africa  Algeria   Algiers    3            65.7
# 3            Africa  Algeria   Algiers    4            69.8
# 4            Africa  Algeria   Algiers    5            63.8
# ...             ...      ...       ...  ...             ...
# 8785  North America       US  Cheyenne   26            51.7
# 8786  North America       US  Cheyenne   27            55.5
# 8787  North America       US  Cheyenne   28            38.5
# 8788  North America       US  Cheyenne   29            36.8
# 8789  North America       US  Cheyenne   30            36.9
#
# [8790 rows x 5 columns]

# %%
# teplota.loc["Helsinky"]
# print(teplota.loc["Miami Beach"])
# print(teplota.loc["Tokyo"])

tri_mesta = pandas.DataFrame(teplota)
tri_mesta = tri_mesta.set_index('City')
tri_mesta
# Out:
#                  Region  Country  Day  AvgTemperature
# City
# Algiers          Africa  Algeria    1            62.0
# Algiers          Africa  Algeria    2            62.2
# Algiers          Africa  Algeria    3            65.7
# Algiers          Africa  Algeria    4            69.8
# Algiers          Africa  Algeria    5            63.8
# ...                 ...      ...  ...             ...
# Cheyenne  North America       US   26            51.7
# Cheyenne  North America       US   27            55.5
# Cheyenne  North America       US   28            38.5
# Cheyenne  North America       US   29            36.8
# Cheyenne  North America       US   30            36.9
#
# [8790 rows x 4 columns]

# %%
tri_mesta.loc["Helsinky"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lukáš\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\Lukáš\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Lukáš\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Lukáš\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ...

# %%
# Vytvoř krabicový graf a porovnej rozsah teplot v těchto městech.

data.plot(kind='box', whis=[0, 100])
plt.show()
